# %%
import slc
# Out:
# N=600, row=8, col=8
# number of iterations = 3000, cost = 0.121144, eta = 1.000000e+00
#
# number of iterations = 3000, cost = 0.011924, eta = 5.000000e-01
# in-samples error = 0.011924
# [[270.   0.]
#  [  0. 210.]]
# out-samples error=0.060982
# [[70.  2.]
#  [ 1. 47.]]
